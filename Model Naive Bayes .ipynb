# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd
# Out:
# StatementMeta(, d6abf867-46cd-4a69-9c1f-feffeb723f61, 4, Finished, Available, Finished)

# %%
spark.conf.set("spark.sql.parquet.datetimeRebaseModeInRead", "LEGACY")
# Out:
# StatementMeta(, d6abf867-46cd-4a69-9c1f-feffeb723f61, 5, Finished, Available, Finished)

# %%
df = spark.sql("SELECT * FROM SephoraLake.sentiment_analysis_comment").toPandas()
print(df)
# Out:
# StatementMeta(, d6abf867-46cd-4a69-9c1f-feffeb723f61, 7, Finished, Available, Finished)
#          author_id product_id  \
# 0       5200955695    P377178
# 1       5448492702    P440484
# 2       2525492189    P433469
# 3       7279560581    P476842
# 4       1340121225    P461161
# ...            ...        ...
# 20185   5067360400    P504637
# 20186  10026585218    P504637
# 20187   6217182209    P504637
# 20188   1492711942    P504637
# 20189   5883475660    P504637
#
#                                              review_text sentiment
# 0                             I saw no change whatsoever   Neutral
# 1                                     Too sticky for me    Neutral
# 2      It looks like they changed the formula when it...   Neutral
# 3      Definition of the word  Garbage  Thats all the...   Neutral
# 4      This did not work for me It made my acne bigge...   Neutral
# ...                                                  ...       ...
# 20185  I received this product complimentary from Hou...  Positive
# 20186  I received this complimentary from Hourglass i...  Positive
# 20187  My skin is loving this treatment it leaves suc...  Positive
# 20188  Im loving it so far It has a great texture tha...  Positive
# 20189  This is so gentle and great to use daily I lik...  Positive
#
# [20190 rows x 4 columns]

# %%
df['sentiment'].unique()
# Out:
# StatementMeta(, d6abf867-46cd-4a69-9c1f-feffeb723f61, 8, Finished, Available, Finished)
# array(['Neutral', 'Negative', 'Positive'], dtype=object)

# %%
vectorizer = CountVectorizer()
# Out:
# StatementMeta(, d6abf867-46cd-4a69-9c1f-feffeb723f61, 9, Finished, Available, Finished)

# %%
X = vectorizer.fit_transform(df['review_text'])
# Out:
# StatementMeta(, d6abf867-46cd-4a69-9c1f-feffeb723f61, 10, Finished, Available, Finished)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df['sentiment'], test_size=0.3, random_state=42)
# Out:
# StatementMeta(, d6abf867-46cd-4a69-9c1f-feffeb723f61, 11, Finished, Available, Finished)

# %%
# Training model
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# StatementMeta(, d6abf867-46cd-4a69-9c1f-feffeb723f61, 12, Finished, Available, Finished)
# MultinomialNB()

# %%
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# StatementMeta(, d6abf867-46cd-4a69-9c1f-feffeb723f61, 13, Finished, Available, Finished)
# Accuracy: 0.883605745418524
# Classification Report:
#                precision    recall  f1-score   support
#
#     Negative       0.59      0.21      0.31       639
#      Neutral       0.70      0.06      0.10       125
#     Positive       0.90      0.98      0.94      5293
#
#     accuracy                           0.88      6057
#    macro avg       0.73      0.42      0.45      6057
# weighted avg       0.86      0.88      0.85      6057
